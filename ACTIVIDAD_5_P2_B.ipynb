# %% [markdown]
# <a href="https://colab.research.google.com/github/IASALOMON33/IASALOMON33-ACTIVIDAD-5-Uso-de-estructuras-y-sentencias-de-control-en-Python/blob/Actividad-5-Parte2A/ACTIVIDAD_5_P2_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 5 P2 B

# %%
diccionario={
    "Estos celos": ["Vicente Fernandez","para siempre", "36 minutos", "mariachi/rancheras"],
    "Tristes recuerdos": ["Antonio Aguilar","corridos y rancheras", "32 minutos", "banda/ranchera"]
}
for clave, valor in diccionario.items():
    print("clave:" ,clave)
    print("valor" , valor)
# Out:
# clave: Estos celos
# valor ['Vicente Fernandez', 'para siempre', '36 minutos', 'mariachi/rancheras']
# clave: Tristes recuerdos
# valor ['Antonio Aguilar', 'corridos y rancheras', '32 minutos', 'banda/ranchera']
