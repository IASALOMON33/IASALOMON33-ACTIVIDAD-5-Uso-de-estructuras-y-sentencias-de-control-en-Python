# %% [markdown]
# <a href="https://colab.research.google.com/github/IASALOMON33/IASALOMON33-ACTIVIDAD-5-Uso-de-estructuras-y-sentencias-de-control-en-Python/blob/main/Actividad5Parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ACTIVIDAD 5 PARTE 1

# %%
numero=[5,10,8,6,7]
numero.insert(2,4)
print(numero)


numero=[5,10,4,8,6,7]
numero.append(3)
print(numero)

palabra=["carolina","tana","jesus","nadir","salomon"]
palabra.insert(2,"hamila")
print(palabra)

palabra=["carolina","tana","jesus","nadir","salomon"]
palabra.append("anapaula")
print(palabra)

cadena="la casa rosa"
cantidad =len(cadena)
print("cantidad de caracteres es: " , cantidad)

cad_may=cadena.upper()
print("cadena en mayusculas",cad_may)


diccionario= {"a":"agua",
              "b":"barco",
              "c":"casa",
              "d":"dado"}
diccionario["e"]="elefante"

print(diccionario)

del diccionario["c"]
print(diccionario)

diccionario_cantidad=len(diccionario)

print("cantidad de elementos del diccionarios",diccionario_cantidad)
