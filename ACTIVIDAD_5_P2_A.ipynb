# %% [markdown]
# <a href="https://colab.research.google.com/github/IASALOMON33/IASALOMON33-ACTIVIDAD-5-Uso-de-estructuras-y-sentencias-de-control-en-Python/blob/Actividad-5-Parte2A/ACTIVIDAD_5_P2_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ACTIVIDAD 5 P2 A

# %%
num_personas = int(input("cuantas personas accesan al cine"))

for i in range(num_personas):
        edad = int(input(f"ingresa la edad de la persona {i + 1}"))
        if (edad < 3):
            print("entrada gratuita")
        elif (edad >= 3 and edad <=12):
            print("El costo del boleto es de $10")
        else :
            print("el costo del boleto es de $15")
# Out:
# cuantas personas accesan al cine 3
# ingresa la edad de la persona 1 13
# el costo del boleto es de $15
# ingresa la edad de la persona 2 30
# el costo del boleto es de $15
# ingresa la edad de la persona 3 12
# El costo del boleto es de $10
